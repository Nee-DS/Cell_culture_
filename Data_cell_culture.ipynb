# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### For file 'lc_ms_raw_data.xlsx' sheet "Data"
# >the NaN values is dropped and the rows reduces to 48 from 66
# >we can groupby the Control and Ikaros and get the content with time
# >need more insights on the columns information

# %%
df1 = pd.read_excel (r'lc_ms_raw_data.xlsx', sheet_name='Data')
len(df1)
# Out:
# 66

# %%
df1_1=df1.dropna()
len(df1_1)
# Out:
# 48

# %%
df1_1.head()
# Out:
#    order  biol batch time point condition                          label  \
# 4      5        11.0         0h   Control   1358BZU_0025_A1_11_0_Control
# 5      6        11.0         0h    Ikaros    1358BZU_0026_A1_11_0_Ikaros
# 6      7        11.0         6h    Ikaros    1358BZU_0030_A1_11_6_Ikaros
# 7      8        11.0         6h   Control   1358BZU_0029_A1_11_6_Control
# 8      9        11.0        18h   Control  1358BZU_0033_A1_11_18_Control
#
#              Id  exp batch  L-histidine  L-Histidine-13C  L-4-hydroxyproline  \
# 4  1358BZU_0025          1     8235.722        29538.568            3133.795
# 5  1358BZU_0026          1    11917.588        30157.824            4762.443
# 6  1358BZU_0030          1    12345.035        32541.709            4876.142
# 7  1358BZU_0029          1    14604.598        35689.855            5837.459
# 8  1358BZU_0033          1    15270.735        30916.240            5976.044
#
# ...

# %% [markdown]
# ## For file 'lc_ms_raw_data.xlsx' sheet 'IS'
# >there is no missing value
# > and has 71 rows

# %%
df2= pd.read_excel (r'lc_ms_raw_data.xlsx', sheet_name='IS')
df2.head()
# Out:
#              Unnamed: 0  Unnamed: 1  L-Histidine-13C     Asn_13C  \
# 0  1358BZU_0001Blank_A1         NaN            0.625       0.784
# 1  1358BZU_0001Blank_B1         NaN        29804.260  135452.719
# 2     1358BZU_0001QC_A1         NaN        29214.545  132061.594
# 3     1358BZU_0001QC_B1         NaN        28727.332  132556.797
# 4       1358BZU_0025_A1         NaN        29538.568  134959.109
#
#    o-phosphoethanolamine13C  L-Asparagine-13C  L-Serine-13C      Arg13C  \
# 0                     0.000             0.703         0.382       0.159
# 1                   465.414        135452.719    228117.531  317246.156
# 2                   397.551        132061.594    218418.016  303464.438
# 3                   401.764        133122.141    219845.828  307203.063
# 4                   350.705        134959.109    222457.547  348527.406
#
#    L-Glutamine-13C  Glycine-13C  ...     Tyr13C  L-lysine-13C     Trp13C  \
# ...

# %%
df2.isnull().values.any()
# Out:
# True

# %%
df2.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'L-Histidine-13C', 'Asn_13C',
#        'o-phosphoethanolamine13C', 'L-Asparagine-13C', 'L-Serine-13C',
#        'Arg13C', 'L-Glutamine-13C', 'Glycine-13C', 'L-homoserine-13C',
#        'L-asparctic acid-13C', 'L-glutamic acid-13C', 'L-threonine-13C',
#        'citrulline-13C', 'ethanolamine-13C', 'gamma-aminobutyric acid-13C',
#        'L-alanine-13C', ' 5-aminolevulinic acid-13C',
#        'gamma-L-glutamyl-L-alanine-13C', 'L-proline-13C',
#        'L-2-aminoadipic acid-13C', 'L-alpha-aminobutyric acid-13C',
#        'Ornithine-13C', 'Tyr13C', 'L-lysine-13C', 'Trp13C', 'L-isoleucine-13C',
#        'L-leucine-13C', 'L-phenylalanine-13C', 'putrescine-13C', 'Met13C',
#        'Val13C', 'spermine13C'],
#       dtype='object')

# %%
del df2['Unnamed: 1']

# %%
df2.head()
# Out:
#              Unnamed: 0  L-Histidine-13C     Asn_13C  \
# 0  1358BZU_0001Blank_A1            0.625       0.784
# 1  1358BZU_0001Blank_B1        29804.260  135452.719
# 2     1358BZU_0001QC_A1        29214.545  132061.594
# 3     1358BZU_0001QC_B1        28727.332  132556.797
# 4       1358BZU_0025_A1        29538.568  134959.109
#
#    o-phosphoethanolamine13C  L-Asparagine-13C  L-Serine-13C      Arg13C  \
# 0                     0.000             0.703         0.382       0.159
# 1                   465.414        135452.719    228117.531  317246.156
# 2                   397.551        132061.594    218418.016  303464.438
# 3                   401.764        133122.141    219845.828  307203.063
# 4                   350.705        134959.109    222457.547  348527.406
#
#    L-Glutamine-13C  Glycine-13C  L-homoserine-13C  ...     Tyr13C  \
# 0            0.213        4.020             0.000  ...      0.000
# 1      1244240.500   176739.547         16720.672  ...  66730.141
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71 entries, 0 to 70
# Data columns (total 33 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Unnamed: 0                      66 non-null     object
#  1   L-Histidine-13C                 66 non-null     float64
#  2   Asn_13C                         67 non-null     float64
#  3   o-phosphoethanolamine13C        68 non-null     float64
#  4   L-Asparagine-13C                69 non-null     float64
#  5   L-Serine-13C                    69 non-null     float64
#  6   Arg13C                          69 non-null     float64
#  7   L-Glutamine-13C                 69 non-null     float64
#  8   Glycine-13C                     69 non-null     float64
#  9   L-homoserine-13C                69 non-null     float64
#  10  L-asparctic acid-13C            69 non-null     float64
#  11  L-glutamic acid-13C             69 non-null     float64
# ...

# %% [markdown]
# ### For file 'STATegra_RNAseq_allSamples_counts.xls'
# > there are no missing values
# >has 12762 rows

# %%
df3=pd.read_excel(r'STATegra_RNAseq_allSamples_counts.xls')

# %%
df3.head()
# Out:
#            Unnamed: 0  ExpBatch_4_Ctr_0H  ExpBatch_5_Ctr_0H  \
# 0  ENSMUSG00000000001               3336               3584
# 1  ENSMUSG00000000028               5801               7374
# 2  ENSMUSG00000000031                 33                 51
# 3  ENSMUSG00000000056               5925               4769
# 4  ENSMUSG00000000078                656                436
#
#    ExpBatch_6_Ctr_0H  ExpBatch_1_Ctr_2H  ExpBatch_2_Ctr_2H  ExpBatch_3_Ctr_2H  \
# 0               6999               3565               4574               1794
# 1              10889               6588               8138               7617
# 2                 50                 17                 39                 18
# 3               5311               2905               5846               2615
# 4                827                444                698                471
#
#    ExpBatch_1_Ctr_6H  ExpBatch_2_Ctr_6H  ExpBatch_3_Ctr_6H  ...  \
# 0               4682               4290               1378  ...
# ...

# %%
len(df3)
# Out:
# 12762

# %%
df3.isnull().values.any()
# Out:
# False

# %%
#df4=pd.read_csv(r'Proteomics_01_uniprot_canonical_normalized.txt')
